# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Pratheba\Downloads\framingham.csv")

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# male                  0
# age                   0
# education           105
# currentSmoker         0
# cigsPerDay           29
# BPMeds               53
# prevalentStroke       0
# prevalentHyp          0
# diabetes              0
# totChol              50
# sysBP                 0
# diaBP                 0
# BMI                  19
# heartRate             1
# glucose             388
# TenYearCHD            0
# Unnamed: 16        4238
# dtype: int64

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
df.shape
# Out:
# (4238, 17)

# %%
df.head(5)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  Unnamed: 16
# ...

# %%
import seaborn as sns

# %%
sns.barplot(df.cigsPerDay)
# Out:
# C:\Users\Pratheba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cigsPerDay'>

# %%
sns.scatterplot()
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize =(12, 5))
plt.boxplot(df)
plt.show()

# %%
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 
axs.hist(df)
plt.show()
# Out:
# C:\Users\Pratheba\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6623: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\Users\Pratheba\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6624: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %%
df['cigsPerDay'].mean()
# Out:
# 9.003088619624615

# %%
df['cigsPerDay'].fillna((df['cigsPerDay'].mean()), inplace=True)

df['cigsPerDay'].interpolate()
# Out:
# 0        0.0
# 1        0.0
# 2       20.0
# 3       30.0
# 4       23.0
#         ...
# 4233     1.0
# 4234    43.0
# 4235    20.0
# 4236    15.0
# 4237     0.0
# Name: cigsPerDay, Length: 4238, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4238 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# ...

# %%
d=df['education'].median()

# %%
d
# Out:
# 2.0

# %%
df['education'].fillna(d,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4238 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4238 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# ...

# %%
df.drop('Unnamed: 16',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4238 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4238 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay           0
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df['BPMeds'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
df['BPMeds'].fillna((df['BPMeds'].mode()[0]), inplace=True)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
c=df['totChol'].mean()

# %%
c
# Out:
# 236.72158548233045

# %%
df['totChol'].fillna(c,inplace=True)

# %%
c=df['totChol'].mean()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4238 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4238 non-null   float64
#  5   BPMeds           4238 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4238 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df['totChol'].round(3)
# Out:
# 0       195.0
# 1       250.0
# 2       245.0
# 3       225.0
# 4       285.0
#         ...
# 4233    313.0
# 4234    207.0
# 4235    248.0
# 4236    210.0
# 4237    269.0
# Name: totChol, Length: 4238, dtype: float64

# %%
df.head(5)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
b=df['BMI'].mean()

# %%
df['BMI'].fillna(b,inplace=True)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df['heartRate'].interpolate()
# Out:
# 0       80.0
# 1       95.0
# 2       75.0
# 3       65.0
# 4       85.0
#         ...
# 4233    66.0
# 4234    65.0
# 4235    84.0
# 4236    86.0
# 4237    80.0
# Name: heartRate, Length: 4238, dtype: float64

# %%
e=df['heartRate'].interpolate(method='linear',limit_direction='backward',limit=1)

# %%
e
# Out:
# 0       80.0
# 1       95.0
# 2       75.0
# 3       65.0
# 4       85.0
#         ...
# 4233    66.0
# 4234    65.0
# 4235    84.0
# 4236    86.0
# 4237    80.0
# Name: heartRate, Length: 4238, dtype: float64

# %%
df['heartRate'].fillna(e,inplace=True)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            0
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.loc[680,:]
# Out:
# male                 0.00
# age                 55.00
# education            1.00
# currentSmoker        0.00
# cigsPerDay           0.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         0.00
# diabetes             0.00
# totChol            225.00
# sysBP              136.50
# diaBP               85.50
# BMI                 20.56
# heartRate           60.00
# glucose             90.00
# TenYearCHD           0.00
# Name: 680, dtype: float64

# %%
df['glucose'].mean()
# Out:
# 81.96675324675324

# %%
df['glucose'].fillna((df['glucose'].mean()), inplace=True)

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
fig = plt.figure(figsize =(10, 7))
plt.boxplot(df)
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(df.glucose)
# Out:
# C:\Users\Pratheba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='glucose'>

# %%
df['age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.corr('pearson',1)
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.028979   0.017205       0.197596    0.316807
# age             -0.028979  1.000000  -0.163547      -0.213748   -0.192366
# education        0.017205 -0.163547   1.000000       0.018273    0.007916
# currentSmoker    0.197596 -0.213748   0.018273       1.000000    0.766970
# cigsPerDay       0.316807 -0.192366   0.007916       0.766970    1.000000
# BPMeds          -0.051545  0.120955  -0.010365      -0.048358   -0.045663
# prevalentStroke -0.004546  0.057655  -0.035150      -0.032988   -0.032706
# prevalentHyp     0.005313  0.307194  -0.081021      -0.103260   -0.065947
# diabetes         0.015708  0.101258  -0.038136      -0.044295   -0.037063
# totChol         -0.069974  0.260270  -0.022479      -0.046285   -0.026025
# sysBP           -0.035989  0.394302  -0.128273      -0.130230   -0.088505
# diaBP            0.057933  0.206104  -0.061719      -0.107746   -0.056391
# ...

# %%
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(50,50)
plt.show()

# %%
from scipy.stats import pearsonr

# %%
df['age'].plot()
# Out:
# <AxesSubplot:>

# %%
## box plots
fig = plt.figure(figsize =(10, 7))
plt.boxplot(df)
plt.show()

# %%
### line graph
plt.plot(df['age'],df['BMI'])
plt.show()

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#histogram
plt.hist(df['age'])
plt.show()

# %%
fig,ax=plt.subplots(figsize=(5,5))
plt.hist(df['age'])
plt.show()

# %%
plt.scatter(df['age'],df['BMI'])
plt.xlabel('AGE')
plt.ylabel('BMI')
plt.title('AGE vs BMI')
plt.show()

# %%
plt.bar(df['education'],df['age'])
plt.xlabel('EDUCATION')
plt.ylabel('AGE')
plt.title('EDUCATION vs AGE')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(50,50)
plt.show()
